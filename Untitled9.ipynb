# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahulrawat00/Basic-Code-/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# print(
#     'directions to open: \n'
#     'Si:south in \n'-
#     'wi:west in \n'
#     'ei:east in \n'
#     'ni:north in \n'
# )

# open_direction = input("enter the direction:")

# if open_direction =='si':
#   next_direction= input("enter the direction you want to go:")
#   if next_direction == 'eo' or next_direction == 'so':
#     print('vehicles for eastOut and u-turn are stop')
#     print('nortIn  lights green')
#     print('eastIn lights red')
#     # print('norhtOut side lights open')
#     # print("southOut side lights open")

#   elif next_direction =='no':
#     print("SouthIn side lights open")
#     # print('NorthOut side lights open')
#     print('NorthIn side lights open')
#     # print("SouthOut side lights open")

# elif open_direction =="ni":
#    next_direction= input("enter the direction you want to go:")
#    if next_direction == 'wo'or next_direction =='no':
#     print('vehicles for westOut or u-turn  are stop')
#     print('eastIn ligths red')
#     # print('norhtOut side lights open')
#     print("southIn side lights red")
#     print('westIn lights red')

#    elif next_direction =='so':
#     print("SouthIn side lights green")
#     # print('NorthOut side lights open')
#     print('NorthIn side lights open')
#     # print("SouthOut side lights open")

# elif open_direction == 'wi':
#    next_direction= input("enter the direction you want to go:")
#    if next_direction == 'wo':
#     print('vehicles for southOut or u-turn  is stop')
#     print('eastIn ligths red')
#     # print('norhtOut side lights open')
#     print("southIn side lights red")

#    elif next_direction =='eo':
#     print("westIn lights green")
#     print("SouthIn side lights red")
#     # print('NorthOut side lights open')
#     print('NorthIn side lights red')

#     # print("SouthOut side lights open")
# elif open_direction == 'ei':
#  next_direction= input("enter the direction you want to go:")
#    if next_direction == 'no' or next_direction == "eo":
#     print('lights for nouthOut or u-turn  is red')
#     print('eastIn ligths red')
#     # print('norhtOut side lights open')
#     print("southIn side lights red")

#    elif next_direction =='wo':
#     print("westIn lights green")
#     print("westIn lights green")
#     print("SouthIn side lights red")
#     # print('NorthOut side lights open')
#     print('NorthIn side lights red')


# else:
#   print("enter right direction. please!")

# %%
#1+2+3+4+5+............................998+999+1000
# n = int(input("enter the  last number:"))
# a = int(input("enter the first number:"))
# d= int(input("enter the  difference number:"))
# calculate = n/2*(a+n)
# print(calculate)



# a = int(input('enter the first number:'))
# a2 = int(input('enter the second number:'))
# n = int (input('enter the last number:'))
# d = a2-a

# an =a + (n-1)*d
# print(an)

# user_input =int(input("enter a number for factorial:"))
# factorial= 1
# for i in range (1 , user_input+1 ):
#   factorial = factorial*i

# print(factorial)



# a, b = 10,5
# a = a+b
# b= a-b
# print(a,b)
# n = int(input("enter the number:"))
# first_term = 0
# second_term = 1
# print(first_term)
# print(second_term)
# for i in range(2,n):
#   third_term = first_term+second_term
#   first_term = second_term
#   second_term = third_term
#   print(third_term )


# user_input =int(input("enter the number of input:"))



# factorial= 1
# sum = 0


# for i in range (1,user_input+1):
#   factorial = factorial*i
#   sum += factorial

# print(f"factorial :{factorial}")
# print(f"sum:{sum}")


# n = int(input("enter the number to check palindromme:"))
# reverse=0
# user_input =n
# while n>0:

#   digit = n%10
#   n = int(n/10)
#   reverse=reverse*10+digit
# if reverse == user_input:
#   print(f"{reverse} is palindrome")
# else:
#   print("not a palindrome")




# sum = 0
# for i in range (1,100+1,):
#   sqr = i*i
#   sum += sqr
# print(sum)
# n = int(input("enter the number for prime number:"))
# for num in range(2, n):

#   for i in range(2,num):


#     if num%i ==0:
#       break
#   else:
#     print(num)


# for num in range(2,n):
#   if n==2:


# n = int(input("enter the number :"))













# user_input= input('enter a word to check palindrome:')
# palindrom = ""
# for i in user_input:
#    palindrom = i+palindrom


# if palindrom == user_input:
#   print(f"{palindrom} is palindrom")
# else:
#   print(f"{palindrom} not a palindrom")




# def addition(n):
#     count =0
#     for i in range(n):
#         count +=i

#     return count


# print(addition(10))



# def numberCheck(n):
#     for i in range(n):
#         if i%2!=0:
#             print(f"{i} is a odd number")
#         else:
#             print(f"{i} is even number")

# # numberCheck(10)

# # def numCheck(j):

# #     if j%2!=0:
# #         print(f"{j} is a odd number")
# #     else:
# #         print(f"{j} is even number")

# # numCheck(2)




# def fibonnaci(n):
#     first_term = 0
#     second_term = 1
#     print(first_term)
#     print(second_term)
#     for i in range(2,n):
#         third_term = first_term+second_term
#         first_term = second_term
#         second_term = third_term
#         print(third_term )




# fibonnaci(10)


# def factorial(n):
#     factorial = 1
#     for i in range (1,n):
#         factorial = factorial*i
#         print(factorial)

# factorial(5)



# def prime_number(n):
#   for i in range(2,n):
#     for j in range(2,i):
#         if i%j==0:
#             break
#     else:
#       print(i)


# prime_number(10)





# def sum_of_fact(n):

#   sum = 0
#   for i in range (1,n+1,2):
#     factorial = 1
#     for j in range(1,i+1):


#       factorial = j*factorial
#     sum += factorial

#     print(factorial)
#     print(sum)



# print(sum_of_fact(5))





# def add(*args):
#   sum = 0
#   for i in args:
#     sum +=i

#   print(sum)


# add(2,3,4,5)






# def values(**kwargs):
#   return kwargs

# values(name='rahul', surname= 'rawat')



# def key_values(**kwargs):
#   for key, value in kwargs.items():
#     print(f" {value}")


# key_values(name="rahul", surname= 'rawat')



# a = lambda x :x*x

# print(a(5))
# def sum_of_fact(n):
#   sum = 0
#   fact =1
#   for i in range(1,n+1):
#     fact = fact*i
#     if i%2!=0:
#       sum += fact
#   print(sum)

# sum_of_fact(5)



# def sumOffact(n):
#   sum = 0
#   for i in range(1,n+1,4):
#     fact= 1
#     for i in range(1,i+1):
#       fact = i*fact
#       # print(fact)
#     sum += fact
#     print(sum)


# sumOffact(5)


# def fact_sum(n):
#   sum = 0
#   fact =1
#   for i in range (1,n+1):
#     fact = fact*i

#     if (i)%4==1:
#      sum+=fact
#   print(sum)
#   print(fact)

# fact_sum(13)



# num = 2344
# reverse = 0
# while num>0:
#   digit = num%10
#   reverse +=digit
#   num = num//10
# print(reverse)


# def fibonacci(n):
#   first_digit = 0
#   second_digit =1
#   print(first_digit, second_digit)
#   third_digit=0
#   for i in range(2,n+1):
#     third_digit = first_digit+second_digit
#     first_digit = second_digit
#     second_digit = third_digit
#     print(third_digit)
# fibonacci(10)

# def factorial_sum(n):
#   sum = 0
#   fact = 1
#   for i in range(1,n+1):
#     fact = fact*i
#     if i%2!=0:
#       sum += fact

#   print(sum)
# factorial_sum(7)




# user_gen = input('enter your gender(men , women   ):-')
# user_weight= int(input("enter your weight(kg):-"))
# user_height = int(input("enter your height(cm):-"))
# user_age= int(input("enter your age:-"))

# if user_gen =='men':
#   bmr = (10 * user_weight)+ (6.25 * user_height) - (5 * user_age) +5
#   print(bmr)

# elif user_gen == "women":
#   bmr = (10 * user_weight)+(6.25*user_height)-(5*user_age)-161

#   print(bmr)



# a= 10
# b=15
# if a<b:
#   num =a
# else:
#   num = b

# for i in range(1,num+1):
#   if a%i==0 and b%i==0:
#     hcf =i
# print(f"hcf:-{hcf}")

# Lcm = a * b/hcf
# print(f'lcm:-{Lcm}')



# num1= int(input('enter your number:-'))
# num2= int(input('enter your number:-'))


# if num1>num2:
#   greatnumber = num1
# else:
#   greatnumber = num2


# for i in range (greatnumber, num1*num2+1):
#   if i%num1 == 0 and i%num2 ==0:
#     lcm =i
#     break
#    print(lcm)



# def factorial(n):
#   if n==0 or n ==1:
#     return 1
#   else:
#     return n*factorial(n-1)


# factorial(5)

# n= 10
# def fibonnaci(n):
#   if n==0:
#     return 0
#   elif n==1:
#     return  1
#   else:
#     return fibonnaci(n-1)+fibonnaci(n-2)


# for i in range (n):
#  print(fibonnaci(i))


# name = ' rahul singh rawat '

# print(name.replace(" ",""))


# print(name.startswith(' '))
# print(name.endswith('t'))





# name = input("enter your name:")

# reverse = ""
# for char in name:
#   reverse = char+reverse
# print(reverse )

# if reverse == name:
#   print(f"{reverse} is palindrome")
# else:
#   print('no a palindrome')



# name = "pqpqppppp"
# count = 0
# for char in name:
#   if char =='p':
#     count +=1

# print(count)



# n= int(input('enter the number :-'))
# count= 0
# sum = 0
# for num in range(n+1):
#   sum+=num

#   if num%2==0 or num%3==0 or num%5==0:
#     count +=num


# print(sum-count)

# a= [1,2,3,5]
# print(a[:-2])

# no_of_item = int(input("enter your amount:"))
# discount=[]
# discount_price = []
# total_bill =0

# amount = []
# item = []
# price = 0
# for i in range(no_of_item):

#   item_name = input(f"enter your item name {i+1}:")
#   item.append(item_name)
#   price  = int(input(f'enter you item price {i+1}:  '))
#   amount.append(price)
#   discounts  = int(input(f'enter you item discount {i+1}:  '))
#   discount.append(discounts)
#   discount_prices = price * discounts/100
#   prices = price - discount_prices
#   discount_price.append(prices)
#   total_bill += prices





# print(total_bill)
# print(item)

# print(discount_price)




# no_of_item = int(input("enter your amount:"))
# discount=[]
# discount_price = []
# total_bill =0

# amount = []
# item = []
# price = 0
# for i in range(no_of_item):

#   item_name = input(f"enter your item name {i+1}:")
#   item.append(item_name)
#   price  = int(input(f'enter you item price {i+1}:  '))
#   amount.append(price)
#   discounts  = int(input(f'enter you item discount {i+1}:  '))
#   discount.append(discounts)
#   discount_prices = price * discounts/100
#   prices = price - discount_prices
#   discount_price.append(prices)
#   total_bill += prices




# bill_pay = total_bill *15/100
# bill = total_bill-bill_pay
# coupon_name = input('enter your coupon number:-')
# if coupon_name =='chkfir29':
#   coupon_amt = bill * 29/100
#   bill = bill -coupon_amt
#   print(f"amount with coupon number :- {bill}")
# else:
#   print(bill)
# print(f"total bill after 15% discount:-{bill}")
# print(f"bill before discount:-  {total_bill}")
# print(item)

# print(discount_price)

a=[1,2,3,4,5,6]
print(a[1:])
print
# Out:
# [2, 3, 4, 5, 6]

# %% [markdown]
# # New Section
